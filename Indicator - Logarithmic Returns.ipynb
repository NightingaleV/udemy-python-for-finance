# %%
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
PG = wb.DataReader("PG", data_source="yahoo", start="1995-1-1") #import dat

# %%
PG["log_return"] = np.log(PG["Adj Close"] / PG["Adj Close"].shift(1))

# %%
PG["log_return"].plot(figsize=(8,5))
plt.show()

# %%
log_return_average = PG["log_return"].mean() * 25000

# %%
result = round(log_return_average, 2)
print ("Prumerna vydelecnost je " + str(result) + " %")
# Out:
# Prumerna vydelecnost je 10.21 %
